# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="*****") # get your api_key from https://universe.roboflow.com/alidatasets/rsi-test
project = rf.workspace("alidatasets").project("rsi-test")
version = project.version(1)
dataset = version.download("folder")

# %%
# !pip install -U ultralytics

# %%
# !mv {dataset.location}/valid {dataset.location}/val

# %%
#remove duplicate labels

# !rm -rf "/content/RSI-Test-1/test/person p"*
# !rm -rf "/content/RSI-Test-1/train/person p"*
# !rm -rf "/content/RSI-Test-1/val/person p"*

# %%
# !yolo task=classify mode=train model=yolo11n-cls.pt data={dataset.location} epochs=25
# Out:
# Ultralytics 8.3.11 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
